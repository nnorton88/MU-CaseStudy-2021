# %% [markdown]
# # Target Variables

# %% [markdown]
# This will investigate our 4 main target variables and their potential correlations with other variables.

# %% [markdown]
# Importing necessary libraries, tools, data.

# %%
# !pip install joblib

import pandas as pd
import numpy as np
import joblib
from scipy.stats import chi2_contingency
from time import time
import plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import ipywidgets as ipw
from ipywidgets import HBox, VBox,Label
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = joblib.load ('GroupedAndUngroupedData.pkl')

# %%
results = joblib.load ('Chi2Results.pkl')

# %% [markdown]
# # Video Game Use Frequency

# %%
VGresults=results[results['Y'].isin(['videoGameUseFrequency_Groups'])].sort_values('p')

# %%
DemoVGresults=VGresults[VGresults['XCategory'].isin(['Demographics'])].sort_values('p')

DemoVGresults.head(10)
# Out:
#         XCategory              YCategory                             X  \
# 55   Demographics  InternetUseVideoGames                 gender_Groups
# 223  Demographics  InternetUseVideoGames       internetAccessOtherHome
# 195  Demographics  InternetUseVideoGames            internetAccessNone
# 167  Demographics  InternetUseVideoGames     internetAccessMobilePhone
# 111  Demographics  InternetUseVideoGames    internetAccessLaptopTablet
# 83   Demographics  InternetUseVideoGames       internetAccessCafeKiosk
# 251  Demographics  InternetUseVideoGames         internetAccessOwnHome
# 363  Demographics  InternetUseVideoGames            internetAccessWork
# 139  Demographics  InternetUseVideoGames         internetAccessLibrary
# 307  Demographics  InternetUseVideoGames  internetAccessSetting_Groups
#
#                                 Y       chi2             p  dof  \
# 55   videoGameUseFrequency_Groups  42.664012  3.872791e-07    7
# ...

# %%
IVGVGresults=VGresults[VGresults['XCategory'].isin(['InternetUseVideoGames'])].sort_values('p')

IVGVGresults.head(10)
# Out:
#                   XCategory              YCategory  \
# 1183  InternetUseVideoGames  InternetUseVideoGames
# 1318  InternetUseVideoGames  InternetUseVideoGames
# 1210  InternetUseVideoGames  InternetUseVideoGames
# 1345  InternetUseVideoGames  InternetUseVideoGames
# 1372  InternetUseVideoGames  InternetUseVideoGames
# 1264  InternetUseVideoGames  InternetUseVideoGames
# 1237  InternetUseVideoGames  InternetUseVideoGames
# 1291  InternetUseVideoGames  InternetUseVideoGames
# 805   InternetUseVideoGames  InternetUseVideoGames
# 1156  InternetUseVideoGames  InternetUseVideoGames
#
#                                                 X  \
# 1183                 videoGamePlayingGamer_Groups
# 1318          videoGameTypeMultiplayerCoop_Groups
# 1210            videoGamePlayingHelpOthers_Groups
# 1345           videoGameTypeMultiplayerPVP_Groups
# 1372             videoGameTypeSingleplayer_Groups
# 1264    videoGamePlayingMoralEthicalIssues_Groups
# ...

# %%
PEVGresults=VGresults[VGresults['XCategory'].isin(['PoliticalEngagement'])].sort_values('p')

PEVGresults.head(10)
# Out:
#                 XCategory              YCategory  \
# 2267  PoliticalEngagement  InternetUseVideoGames
# 2155  PoliticalEngagement  InternetUseVideoGames
# 1483  PoliticalEngagement  InternetUseVideoGames
# 1763  PoliticalEngagement  InternetUseVideoGames
# 1959  PoliticalEngagement  InternetUseVideoGames
# 1791  PoliticalEngagement  InternetUseVideoGames
# 1903  PoliticalEngagement  InternetUseVideoGames
# 2183  PoliticalEngagement  InternetUseVideoGames
# 2127  PoliticalEngagement  InternetUseVideoGames
# 1931  PoliticalEngagement  InternetUseVideoGames
#
#                                          X                             Y  \
# 2267         selfUnderstandPolitics_Groups  videoGameUseFrequency_Groups
# 2155     selfInternetExpressConcern_Groups  videoGameUseFrequency_Groups
# 1483         discussPoliticsFriends_Groups  videoGameUseFrequency_Groups
# 1763              politicalInterest_Groups  videoGameUseFrequency_Groups
# ...

# %%
SocialVGresults=VGresults[VGresults['XCategory'].isin(['SocialViews'])].sort_values('p')

SocialVGresults.head(10)
# Out:
#         XCategory              YCategory  \
# 2743  SocialViews  InternetUseVideoGames
# 2715  SocialViews  InternetUseVideoGames
# 2771  SocialViews  InternetUseVideoGames
# 2379  SocialViews  InternetUseVideoGames
# 2603  SocialViews  InternetUseVideoGames
# 2799  SocialViews  InternetUseVideoGames
# 2631  SocialViews  InternetUseVideoGames
# 2547  SocialViews  InternetUseVideoGames
# 2351  SocialViews  InternetUseVideoGames
# 2575  SocialViews  InternetUseVideoGames
#
#                                            X                             Y  \
# 2743                   protestIllegal_Groups  videoGameUseFrequency_Groups
# 2715                 protestEffective_Groups  videoGameUseFrequency_Groups
# 2771                    protestNormal_Groups  videoGameUseFrequency_Groups
# 2379               govtHelpVulnerable_Groups  videoGameUseFrequency_Groups
# 2603                    peopleTrusted_Groups  videoGameUseFrequency_Groups
# ...

# %%
TSMVGresults=VGresults[VGresults['XCategory'].isin(['TraditionalSocialMedia'])].sort_values('p')

TSMVGresults.head(10)
# Out:
#                    XCategory              YCategory  \
# 3835  TraditionalSocialMedia  InternetUseVideoGames
# 4003  TraditionalSocialMedia  InternetUseVideoGames
# 3975  TraditionalSocialMedia  InternetUseVideoGames
# 3611  TraditionalSocialMedia  InternetUseVideoGames
# 3779  TraditionalSocialMedia  InternetUseVideoGames
# 4059  TraditionalSocialMedia  InternetUseVideoGames
# 3639  TraditionalSocialMedia  InternetUseVideoGames
# 3527  TraditionalSocialMedia  InternetUseVideoGames
# 4199  TraditionalSocialMedia  InternetUseVideoGames
# 3919  TraditionalSocialMedia  InternetUseVideoGames
#
#                                                  X  \
# 3835                  socialMediaUseYouTube_Groups
# 4003         USAPoliticalNewsSourceComedyTV_Groups
# 3975                USAPoliticalNewsCableTV_Groups
# 3611               socialMediaUseFoursquare_Groups
# 3779                   socialMediaUseReddit_Groups
# 4059      USAPoliticalNewsSourceLateNightTV_Groups
# ...

# %% [markdown]
# # Political Party

# %%
Partyresults=results[results['Y'].isin(['USAPoliticalParty_Groups'])].sort_values('p')

# %%
DemoPartyresults=Partyresults[Partyresults['XCategory'].isin(['Demographics'])].sort_values('p')

DemoPartyresults.head(10)
# Out:
#          XCategory            YCategory                             X  \
# 4910  Demographics  PoliticalEngagement                      USAWhite
# 4755  Demographics  PoliticalEngagement           USAEducation_Groups
# 4724  Demographics  PoliticalEngagement                      USABlack
# 4631  Demographics  PoliticalEngagement         langSpokenHome_Groups
# 4662  Demographics  PoliticalEngagement            USAAreaType_Groups
# 4352  Demographics  PoliticalEngagement         internetAccessLibrary
# 4414  Demographics  PoliticalEngagement            internetAccessNone
# 4259  Demographics  PoliticalEngagement                 gender_Groups
# 4817  Demographics  PoliticalEngagement                     USALatino
# 4538  Demographics  PoliticalEngagement  internetAccessSetting_Groups
#
#                              Y        chi2             p  dof  \
# 4910  USAPoliticalParty_Groups   81.731263  3.643546e-16    5
# 4755  USAPoliticalParty_Groups  165.396849  2.869114e-14   50
# ...

# %%
IVGPartyresults=Partyresults[Partyresults['XCategory'].isin(['InternetUseVideoGames'])].sort_values('p')

IVGPartyresults.head(10)
# Out:
#                   XCategory            YCategory  \
# 5189  InternetUseVideoGames  PoliticalEngagement
# 5158  InternetUseVideoGames  PoliticalEngagement
# 5437  InternetUseVideoGames  PoliticalEngagement
# 5127  InternetUseVideoGames  PoliticalEngagement
# 4972  InternetUseVideoGames  PoliticalEngagement
# 5499  InternetUseVideoGames  PoliticalEngagement
# 5282  InternetUseVideoGames  PoliticalEngagement
# 5096  InternetUseVideoGames  PoliticalEngagement
# 5406  InternetUseVideoGames  PoliticalEngagement
# 5003  InternetUseVideoGames  PoliticalEngagement
#
#                                            X                         Y  \
# 5189       internetUseHealthDifficult_Groups  USAPoliticalParty_Groups
# 5158       internetUseGovernmentForms_Groups  USAPoliticalParty_Groups
# 5437                internetUseTravel_Groups  USAPoliticalParty_Groups
# 5127    internetUseGovernmentBenefits_Groups  USAPoliticalParty_Groups
# ...

# %%
PEPartyresults=Partyresults[Partyresults['XCategory'].isin(['PoliticalEngagement'])].sort_values('p')

PEPartyresults.head(10)
# Out:
#                 XCategory            YCategory  \
# 6534  PoliticalEngagement  PoliticalEngagement
# 6174  PoliticalEngagement  PoliticalEngagement
# 5960  PoliticalEngagement  PoliticalEngagement
# 6020  PoliticalEngagement  PoliticalEngagement
# 5990  PoliticalEngagement  PoliticalEngagement
# 5869  PoliticalEngagement  PoliticalEngagement
# 6264  PoliticalEngagement  PoliticalEngagement
# 6714  PoliticalEngagement  PoliticalEngagement
# 6444  PoliticalEngagement  PoliticalEngagement
# 6624  PoliticalEngagement  PoliticalEngagement
#
#                                             X                         Y  \
# 6534                           pyVoted_Groups  USAPoliticalParty_Groups
# 6174                 politicalInterest_Groups  USAPoliticalParty_Groups
# 5960           groupFocusInternational_Groups  USAPoliticalParty_Groups
# 6020                groupFocusNational_Groups  USAPoliticalParty_Groups
# 5990                   groupFocusLocal_Groups  USAPoliticalParty_Groups
# ...

# %%
SocialPartyresults=Partyresults[Partyresults['XCategory'].isin(['SocialViews'])].sort_values('p')

SocialPartyresults.head(10)
# Out:
#         XCategory            YCategory                                     X  \
# 6775  SocialViews  PoliticalEngagement                    gayMarriage_Groups
# 6837  SocialViews  PoliticalEngagement             govtHelpVulnerable_Groups
# 6868  SocialViews  PoliticalEngagement             govtPoorDependence_Groups
# 6744  SocialViews  PoliticalEngagement                abortionIllegal_Groups
# 6806  SocialViews  PoliticalEngagement         govtBusinessRegulation_Groups
# 6899  SocialViews  PoliticalEngagement  immigrationThreatenTradValues_Groups
# 6961  SocialViews  PoliticalEngagement                newsTrustworthy_Groups
# 7209  SocialViews  PoliticalEngagement               protestEffective_Groups
# 6992  SocialViews  PoliticalEngagement                   newsUnbiased_Groups
# 7302  SocialViews  PoliticalEngagement       protestNotRepresentative_Groups
#
#                              Y        chi2             p  dof  \
# ...

# %%
TSMPartyresults=Partyresults[Partyresults['XCategory'].isin(['TraditionalSocialMedia'])].sort_values('p')

TSMPartyresults.head(10)
# Out:
#                    XCategory            YCategory  \
# 8139  TraditionalSocialMedia  PoliticalEngagement
# 8108  TraditionalSocialMedia  PoliticalEngagement
# 8635  TraditionalSocialMedia  PoliticalEngagement
# 8046  TraditionalSocialMedia  PoliticalEngagement
# 7891  TraditionalSocialMedia  PoliticalEngagement
# 7736  TraditionalSocialMedia  PoliticalEngagement
# 8542  TraditionalSocialMedia  PoliticalEngagement
# 7581  TraditionalSocialMedia  PoliticalEngagement
# 7705  TraditionalSocialMedia  PoliticalEngagement
# 7860  TraditionalSocialMedia  PoliticalEngagement
#
#                                            X                         Y  \
# 8139            politicalNewsInterest_Groups  USAPoliticalParty_Groups
# 8108             nationalNewsInterest_Groups  USAPoliticalParty_Groups
# 8635   USAPoliticalNewsSourceComedyTV_Groups  USAPoliticalParty_Groups
# 8046        internationalNewsInterest_Groups  USAPoliticalParty_Groups
# ...

# %% [markdown]
# # Attended Rally

# %%
ARresults=results[results['Y'].isin(['pyAttendedRally_Groups'])].sort_values('p')

# %%
DemoARresults=ARresults[ARresults['XCategory'].isin(['Demographics'])].sort_values('p')

DemoARresults.head(10)
# Out:
#          XCategory            YCategory                             X  \
# 4308  Demographics  PoliticalEngagement       internetAccessCafeKiosk
# 4370  Demographics  PoliticalEngagement         internetAccessLibrary
# 4277  Demographics  PoliticalEngagement                 gender_Groups
# 4556  Demographics  PoliticalEngagement  internetAccessSetting_Groups
# 4928  Demographics  PoliticalEngagement                      USAWhite
# 4773  Demographics  PoliticalEngagement           USAEducation_Groups
# 4463  Demographics  PoliticalEngagement       internetAccessOtherHome
# 4742  Demographics  PoliticalEngagement                      USABlack
# 4525  Demographics  PoliticalEngagement          internetAccessSchool
# 4246  Demographics  PoliticalEngagement                    age_Groups
#
#                            Y       chi2             p  dof  \
# 4308  pyAttendedRally_Groups  74.837892  5.612525e-17    2
# 4370  pyAttendedRally_Groups  57.801654  2.808861e-13    2
# ...

# %%
IVGARresults=ARresults[ARresults['XCategory'].isin(['InternetUseVideoGames'])].sort_values('p')

IVGARresults.head(10)
# Out:
#                   XCategory            YCategory  \
# 5021  InternetUseVideoGames  PoliticalEngagement
# 5052  InternetUseVideoGames  PoliticalEngagement
# 4959  InternetUseVideoGames  PoliticalEngagement
# 4990  InternetUseVideoGames  PoliticalEngagement
# 5083  InternetUseVideoGames  PoliticalEngagement
# 5300  InternetUseVideoGames  PoliticalEngagement
# 5269  InternetUseVideoGames  PoliticalEngagement
# 5610  InternetUseVideoGames  PoliticalEngagement
# 5641  InternetUseVideoGames  PoliticalEngagement
# 5145  InternetUseVideoGames  PoliticalEngagement
#
#                                                 X                       Y  \
# 5021       groupPoliticalIssueInternetRole_Groups  pyAttendedRally_Groups
# 5052            groupPoliticanInternetRole_Groups  pyAttendedRally_Groups
# 4959     groupElectionCampaignInternetRole_Groups  pyAttendedRally_Groups
# 4990       groupLocalCommunityInternetRole_Groups  pyAttendedRally_Groups
# ...

# %%
PEARresults=ARresults[ARresults['XCategory'].isin(['PoliticalEngagement'])].sort_values('p')

PEARresults.head(10)
# Out:
#                 XCategory            YCategory                              X  \
# 6402  PoliticalEngagement  PoliticalEngagement         pyCommentedNews_Groups
# 6432  PoliticalEngagement  PoliticalEngagement     pyContacedPolitican_Groups
# 6492  PoliticalEngagement  PoliticalEngagement         pyEncourageVote_Groups
# 6099  PoliticalEngagement  PoliticalEngagement            groupPoliticalIssue
# 6552  PoliticalEngagement  PoliticalEngagement                 pyVoted_Groups
# 6130  PoliticalEngagement  PoliticalEngagement                 groupPolitican
# 6522  PoliticalEngagement  PoliticalEngagement        pySignedPetition_Groups
# 5886  PoliticalEngagement  PoliticalEngagement  discussPoliticsFriends_Groups
# 5947  PoliticalEngagement  PoliticalEngagement          groupElectionCampaign
# 5916  PoliticalEngagement  PoliticalEngagement   discussPoliticsOthers_Groups
#
#                            Y        chi2              p  dof  \
# ...

# %%
SocialARresults=ARresults[ARresults['XCategory'].isin(['SocialViews'])].sort_values('p')

SocialARresults.head(10)
# Out:
#         XCategory            YCategory  \
# 7413  SocialViews  PoliticalEngagement
# 7506  SocialViews  PoliticalEngagement
# 7351  SocialViews  PoliticalEngagement
# 7444  SocialViews  PoliticalEngagement
# 7475  SocialViews  PoliticalEngagement
# 7382  SocialViews  PoliticalEngagement
# 7258  SocialViews  PoliticalEngagement
# 7134  SocialViews  PoliticalEngagement
# 7010  SocialViews  PoliticalEngagement
# 7165  SocialViews  PoliticalEngagement
#
#                                            X                       Y  \
# 7413           pyDisplayedCauseSymbol_Groups  pyAttendedRally_Groups
# 7506           pySignedUpForCauseInfo_Groups  pyAttendedRally_Groups
# 7351                 pyBoughtForCause_Groups  pyAttendedRally_Groups
# 7444           pyDonatedMoneyForCause_Groups  pyAttendedRally_Groups
# 7475          pyRaisedMoneyForCharity_Groups  pyAttendedRally_Groups
# 7382              pyBoycottedForCause_Groups  pyAttendedRally_Groups
# ...

# %%
TSMARresults=ARresults[ARresults['XCategory'].isin(['TraditionalSocialMedia'])].sort_values('p')

TSMARresults.head(10)
# Out:
#                    XCategory            YCategory  \
# 8343  TraditionalSocialMedia  PoliticalEngagement
# 8219  TraditionalSocialMedia  PoliticalEngagement
# 8529  TraditionalSocialMedia  PoliticalEngagement
# 7599  TraditionalSocialMedia  PoliticalEngagement
# 8312  TraditionalSocialMedia  PoliticalEngagement
# 8591  TraditionalSocialMedia  PoliticalEngagement
# 8405  TraditionalSocialMedia  PoliticalEngagement
# 7568  TraditionalSocialMedia  PoliticalEngagement
# 7878  TraditionalSocialMedia  PoliticalEngagement
# 7909  TraditionalSocialMedia  PoliticalEngagement
#
#                                             X                       Y  \
# 8343             socialMediaUseMyspace_Groups  pyAttendedRally_Groups
# 8219          socialMediaUseFoursquare_Groups  pyAttendedRally_Groups
# 8529     twitterUseDiscussNewsPolitics_Groups  pyAttendedRally_Groups
# 7599             facebookEncourageVote_Groups  pyAttendedRally_Groups
# ...

# %% [markdown]
# # Voted

# %%
Votedresults=results[results['Y'].isin(['pyVoted_Groups'])].sort_values('p')

# %%
DemoVotedresults=Votedresults[Votedresults['XCategory'].isin(['Demographics'])].sort_values('p')

DemoVotedresults.head(10)
# Out:
#          XCategory            YCategory                             X  \
# 4779  Demographics  PoliticalEngagement           USAEducation_Groups
# 4314  Demographics  PoliticalEngagement       internetAccessCafeKiosk
# 4624  Demographics  PoliticalEngagement            internetAccessWork
# 4252  Demographics  PoliticalEngagement                    age_Groups
# 4562  Demographics  PoliticalEngagement  internetAccessSetting_Groups
# 4376  Demographics  PoliticalEngagement         internetAccessLibrary
# 4655  Demographics  PoliticalEngagement         langSpokenHome_Groups
# 4934  Demographics  PoliticalEngagement                      USAWhite
# 4500  Demographics  PoliticalEngagement         internetAccessOwnHome
# 4438  Demographics  PoliticalEngagement            internetAccessNone
#
#                    Y        chi2             p  dof  \
# 4779  pyVoted_Groups  154.728894  7.781428e-23   20
# 4314  pyVoted_Groups   40.997360  1.251804e-09    2
# ...

# %%
IVGVotedresults=Votedresults[Votedresults['XCategory'].isin(['InternetUseVideoGames'])].sort_values('p')

IVGVotedresults.head(10)
# Out:
#                   XCategory            YCategory  \
# 5058  InternetUseVideoGames  PoliticalEngagement
# 5027  InternetUseVideoGames  PoliticalEngagement
# 4965  InternetUseVideoGames  PoliticalEngagement
# 4996  InternetUseVideoGames  PoliticalEngagement
# 5182  InternetUseVideoGames  PoliticalEngagement
# 5089  InternetUseVideoGames  PoliticalEngagement
# 5461  InternetUseVideoGames  PoliticalEngagement
# 5306  InternetUseVideoGames  PoliticalEngagement
# 5275  InternetUseVideoGames  PoliticalEngagement
# 5647  InternetUseVideoGames  PoliticalEngagement
#
#                                               X               Y        chi2  \
# 5058          groupPoliticanInternetRole_Groups  pyVoted_Groups  139.167404
# 5027     groupPoliticalIssueInternetRole_Groups  pyVoted_Groups  122.711625
# 4965   groupElectionCampaignInternetRole_Groups  pyVoted_Groups  114.100111
# 4996     groupLocalCommunityInternetRole_Groups  pyVoted_Groups   95.618039
# ...

# %%
PEVotedresults=Votedresults[Votedresults['XCategory'].isin(['PoliticalEngagement'])].sort_values('p')

PEVotedresults.head(10)
# Out:
#                 XCategory            YCategory  \
# 6377  PoliticalEngagement  PoliticalEngagement
# 6043  PoliticalEngagement  PoliticalEngagement
# 6497  PoliticalEngagement  PoliticalEngagement
# 6013  PoliticalEngagement  PoliticalEngagement
# 5983  PoliticalEngagement  PoliticalEngagement
# 6407  PoliticalEngagement  PoliticalEngagement
# 6437  PoliticalEngagement  PoliticalEngagement
# 6467  PoliticalEngagement  PoliticalEngagement
# 5892  PoliticalEngagement  PoliticalEngagement
# 5922  PoliticalEngagement  PoliticalEngagement
#
#                                             X               Y        chi2  \
# 6377                   pyAttendedRally_Groups  pyVoted_Groups  320.748972
# 6043                groupFocusNational_Groups  pyVoted_Groups  314.781147
# 6497                   pyEncourageVote_Groups  pyVoted_Groups  312.687226
# 6013                   groupFocusLocal_Groups  pyVoted_Groups  312.327782
# ...

# %%
SocialVotedresults=Votedresults[Votedresults['XCategory'].isin(['SocialViews'])].sort_values('p')

SocialVotedresults.head(10)
# Out:
#         XCategory            YCategory                                X  \
# 7357  SocialViews  PoliticalEngagement          pyBoughtForCause_Groups
# 7512  SocialViews  PoliticalEngagement    pySignedUpForCauseInfo_Groups
# 7419  SocialViews  PoliticalEngagement    pyDisplayedCauseSymbol_Groups
# 7450  SocialViews  PoliticalEngagement    pyDonatedMoneyForCause_Groups
# 7388  SocialViews  PoliticalEngagement       pyBoycottedForCause_Groups
# 7481  SocialViews  PoliticalEngagement   pyRaisedMoneyForCharity_Groups
# 7264  SocialViews  PoliticalEngagement            protestIllegal_Groups
# 7326  SocialViews  PoliticalEngagement  protestNotRepresentative_Groups
# 7016  SocialViews  PoliticalEngagement              newsUnbiased_Groups
# 6861  SocialViews  PoliticalEngagement        govtHelpVulnerable_Groups
#
#                    Y        chi2             p  dof  \
# 7357  pyVoted_Groups  226.337170  8.110631e-48    4
# 7512  pyVoted_Groups  224.513242  2.002777e-47    4
# ...

# %%
TSMVotedresults=Votedresults[Votedresults['XCategory'].isin(['TraditionalSocialMedia'])].sort_values('p')

TSMVotedresults.head(10)
# Out:
#                    XCategory            YCategory  \
# 8163  TraditionalSocialMedia  PoliticalEngagement
# 7605  TraditionalSocialMedia  PoliticalEngagement
# 7574  TraditionalSocialMedia  PoliticalEngagement
# 8535  TraditionalSocialMedia  PoliticalEngagement
# 8349  TraditionalSocialMedia  PoliticalEngagement
# 7915  TraditionalSocialMedia  PoliticalEngagement
# 8132  TraditionalSocialMedia  PoliticalEngagement
# 7884  TraditionalSocialMedia  PoliticalEngagement
# 8318  TraditionalSocialMedia  PoliticalEngagement
# 7822  TraditionalSocialMedia  PoliticalEngagement
#
#                                             X               Y        chi2  \
# 8163             politicalNewsInterest_Groups  pyVoted_Groups  107.993316
# 7605             facebookEncourageVote_Groups  pyVoted_Groups  104.139503
# 7574  facebookEncouragePoliticalAction_Groups  pyVoted_Groups  100.924640
# 8535     twitterUseDiscussNewsPolitics_Groups  pyVoted_Groups  100.545926
# ...

# %% [markdown]
# # Conclusions

# %% [markdown]
# The following variables or categories appear multiple times across our target variables. They will be variables that may be of interest later during our predictive modeling.

# %% [markdown]
# Internet Access x 4<br>
# Gender x 3<br>
# Ethnicity x 3<br>
# Education Groups x 3<br>
# Lang Spoken Home x 2<br>
# Age x 2<br>
# <br>
# Internet Use x 4<br>
# Video Game Playing Moral Ethical Issues x 3<br>
# Video Game Playing Learn Society Problems x 2<br>
# Group Political Issue Internet Role x 2<br>
# Group Politician Internet Role x 2<br>
# Group Election Campaign Internet Role x 2<br>
# Group Local Community Internet Role x 2<br>
# Group Social Issue Internet Role x 2<br>
# <br>
# Discuss Politics Friends x 3<br>
# Voted x 2<br>
# Self Understand Politics x 2<br>
# Political Interest x 2<br>
# PY Commented News x 2<br>
# Self Internet Find Political Info x 2<br>
# <br>
# Protest Illegal x 2<br>
# Protest Effective x 2<br>
# Protest Not Respresentative x 2<br>
# Govt Help Vulnerable x 2<br>
# Politicians Country Best Interest x 2<br>
# Govt Business Regulation x 2<br>
# News Unbiased x 2<br>
# <br>
# Twitter use x 3<br>
# USA Political News Source Comedy TV x 2<br>
# National News Interest x 2<br>
# Facebook Post Political Opinions x 2<br>
# Facebook Encourage Vote x 2<br>
# Facebook Post Political Links x 2<br>
